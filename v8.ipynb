# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 872.3/872.3 kB 23.0 MB/s eta 0:00:00
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.1/871.1 kB 17.1 MB/s eta 0:00:00
# ...

# %%
#!yolo predict model=yolov8n.pt source='https://ultralytics.com/images/bus.jpg'!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8
# Out:
# /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 38524, done.
# remote: Counting objects: 100% (1473/1473), done.
# remote: Compressing objects: 100% (767/767), done.
# remote: Total 38524 (delta 951), reused 1108 (delta 705), pack-reused 37051 (from 1)
# Receiving objects: 100% (38524/38524), 30.70 MiB | 15.80 MiB/s, done.
# Resolving deltas: 100% (28137/28137), done.
# Updating files: 100% (651/651), done.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="RysCVkmFBzvYUpY8Ncpu")
project = rf.workspace("solar-panel-damage-detection-iqxtq").project("proj_212")
version = project.version(5)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.8
#     Uninstalling idna-3.8:
#       Successfully uninstalled idna-3.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.85, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Proj_212-5 in yolov8:: 100%|██████████| 1454/1454 [00:11<00:00, 123.58it/s]

# %%
# !ls
# Out:
# Proj_212-5  runs  yolov8n.pt

# %%
# %cd /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8
# !yolo task=detect mode=train model=/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/yolov8n.pt data=/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/data.yaml epochs=75 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !wget - /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8 https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt
# Out:
# --2024-09-01 07:07:52--  http://-/
# Resolving - (-)... failed: Name or service not known.
# wget: unable to resolve host address ‘-’
# /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8: Scheme missing.
# --2024-09-01 07:07:52--  https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from IPython import display
display.clear_output
import ultralytics
ultralytics.checks()
from ultralytics import YOLO
import torch
from IPython.display import display, Image
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.8/78.2 GB disk)

# %%
from ultralytics import YOLO

# %%
# Load a model
model = YOLO('yolov8s.pt')  # You can start from a pre-trained model, e.g., yolov8n.pt

# Train the model
model.train(data='/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/data.yaml', epochs=50, imgsz=640, batch=16)
# Out:
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# Load a model
model = YOLO('yolov8s.pt')  # You can start from a pre-trained model, e.g., yolov8n.pt

# Train the model
model.train(data='/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/data.yaml', epochs=100, imgsz=640, batch=16)
# Out:
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train7/weights/best.pt')
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.85 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/valid/labels.cache... 146 images, 0 backgrounds, 0 corrupt: 100%|██████████| 146/146 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/valid/images/Clean_34_jpg.rf.65014812438bb592afbe6f66cc47aca0.jpg: 1 duplicate labels removed
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 10/10 [00:09<00:00,  1.10it/s]
#                    all        146       1632      0.729      0.748       0.76      0.566
#              Bird-drop         16        229      0.493      0.415      0.389      0.186
# ...

# %%
from ultralytics import YOLO

# Load the trained model (replace 'best.pt' with your model's path)
model = YOLO('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train/weights/best.pt')

# %%
s = '/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images'

# %%
result = model.predict(source=s , save=True , conf=.5 )
# Out:
# image 1/74 /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images/Bird_drop_1_jpg.rf.6c04bffcb85ddd33d04ca5daca6327e1.jpg: 640x640 27 Bird-drops, 6 Defectives, 7.5ms
# image 2/74 /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images/Bird_drop_1_jpg.rf.cd501165fbda64841d4baa8896a15374.jpg: 640x640 23 Bird-drops, 7 Defectives, 17.4ms
# image 3/74 /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images/Bird_drop_83_jpg.rf.50ad701f163d9636a4412c570e7c689e.jpg: 640x640 4 Bird-drops, 2 Defectives, 8.8ms
# image 4/74 /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images/Clean_103_jpg.rf.c51be90e85b7fbe73da3977befd675ab.jpg: 640x640 16 Non-Defectives, 11.4ms
# image 5/74 /content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/test/images/Clean_117_jpg.rf.087aba6090faf5f17bec4c3dee8b5619.jpg: 640x640 6 Non-Defectives, 8.4ms
# ...

# %%
from IPython import display
display.clear_output()
from IPython.display import display,Image

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/F1_curve.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/PR_curve.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/P_curve.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/R_curve.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/confusion_matrix.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/confusion_matrix_normalized.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/results.png')

# %%
Image('/content/drive/MyDrive/Proj_212_yolo.v2i.yolov8/runs/detect/train5/labels.jpg')
